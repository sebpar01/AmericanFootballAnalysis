# %% [markdown]
# Neuronal Network using pytorch

# %% [markdown]
# import all libraries

# %%
import os
import shutil
from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn
import torchvision.models as models
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
import torch.optim as optim

from PIL import Image

# %% [markdown]
# Split dataset

# %%
# Base directory of your dataset
dataset_dir = 'dataset'
train_dir = 'train'
val_dir = 'val'
test_dir = 'test'

# Create directories for the datasets if they don't exist
for dir_name in [train_dir, val_dir, test_dir]:
    for class_name in ["Play", "Time_Between", "Pass", "Run", "Punt", "Kick-Off", "Field_Goal"]:
        os.makedirs(os.path.join(dir_name, class_name), exist_ok=True)

# Group and split all frames according to their videos
for class_name in os.listdir(dataset_dir):
    class_dir = os.path.join(dataset_dir, class_name)
    if os.path.isdir(class_dir):
        # Collecting all videos and their frames
        video_frames = {}
        augmented_frames = []  # For augmented frames
        for frame in os.listdir(class_dir):
            if frame.startswith("aug__"):
                augmented_frames.append(frame)  # Collect augmented frames
            elif '_frame_' in frame and frame.endswith('.jpg'):
                video_name, frame_num = frame.split('_frame_')
                frame_num = frame_num.split('.jpg')[0]
                if video_name not in video_frames:
                    video_frames[video_name] = []
                video_frames[video_name].append(frame)

        # Splitting videos into training, validation, and test sets
        videos = list(video_frames.keys())
        train_videos, temp_videos = train_test_split(videos, test_size=0.3, random_state=42)
        val_videos, test_videos = train_test_split(temp_videos, test_size=0.5, random_state=42)

        # Assigning frames to their respective sets
        for video in train_videos:
            for frame in video_frames[video]:
                shutil.copy(os.path.join(class_dir, frame), os.path.join(train_dir, class_name, frame))
        for video in val_videos:
            for frame in video_frames[video]:
                shutil.copy(os.path.join(class_dir, frame), os.path.join(val_dir, class_name, frame))
        for video in test_videos:
            for frame in video_frames[video]:
                shutil.copy(os.path.join(class_dir, frame), os.path.join(test_dir, class_name, frame))

        # Randomly splitting the augmented frames
        if augmented_frames:
            train_aug, temp_aug = train_test_split(augmented_frames, test_size=0.3, random_state=42)
            val_aug, test_aug = train_test_split(temp_aug, test_size=0.5, random_state=42)
            for frame in train_aug:
                shutil.copy(os.path.join(class_dir, frame), os.path.join(train_dir, class_name, frame))
            for frame in val_aug:
                shutil.copy(os.path.join(class_dir, frame), os.path.join(val_dir, class_name, frame))
            for frame in test_aug:
                shutil.copy(os.path.join(class_dir, frame), os.path.join(test_dir, class_name, frame))
        else:
            print("No augmented frames found in", class_dir)

print("Data has been successfully split.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 37
#      35 for video in train_videos:
#      36     for frame in video_frames[video]:
# ---> 37         shutil.copy(os.path.join(class_dir, frame), os.path.join(train_dir, class_name, frame))
#      38 for video in val_videos:
#      39     for frame in video_frames[video]:
#
# File c:\Users\MCI\anaconda3\envs\football_analysis\Lib\shutil.py:435, in copy(src, dst, follow_symlinks)
#     433 if os.path.isdir(dst):
#     434     dst = os.path.join(dst, os.path.basename(src))
# --> 435 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     436 copymode(src, dst, follow_symlinks=follow_symlinks)
#     437 return dst
#
# File c:\Users\MCI\anaconda3\envs\football_analysis\Lib\shutil.py:260, in copyfile(src, dst, follow_symlinks)
#     258     os.symlink(os.readlink(src), dst)
#     259 else:
# --> 260     with open(src, 'rb') as fsrc:
#     261         try:
#     262             with open(dst, 'wb') as fdst:
#     263                 # macOS
#
# KeyboardInterrupt:

# %% [markdown]
# CNN & LSTM

# %%
class CNNLSTMModel(nn.Module):
    def __init__(self, num_classes, latent_dim=256, lstm_layers=2):
        super(CNNLSTMModel, self).__init__()
        # Load a pretrained ResNet-50 model
        resnet = models.resnet50(pretrained=True)
        # Remove the last Fully-Connected layer to extract features
        self.cnn = nn.Sequential(*list(resnet.children())[:-1])
        
        # LSTM Module
        self.lstm = nn.LSTM(input_size=2048, hidden_size=latent_dim, num_layers=lstm_layers, batch_first=True)
        self.fc = nn.Linear(latent_dim, num_classes)  # Classification layer

    def forward(self, x):
        batch_size, C, H, W = x.size()
        # Process frames through the CNN
        c_out = self.cnn(x)
        c_out = c_out.view(batch_size, -1)
        
        # Process the feature sequence through the LSTM
        lstm_out, _ = self.lstm(c_out.unsqueeze(1))
        # Use only the last output for classification
        final_output = self.fc(lstm_out[:, -1, :])
        return final_output


# Model instantiation
model = CNNLSTMModel(num_classes=7)  # Adjust number of classes

# Output the layers of the model
print(model)

# Or output specific layers
print("CNN Layers:")
print(model.cnn)

print("\nLSTM Layers:")
print(model.lstm)

print("\nClassification Layer:")
print(model.fc)
# Out:
# CNNLSTMModel(
#   (cnn): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (5): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (6): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (7): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (8): AdaptiveAvgPool2d(output_size=(1, 1))
#   )
#   (lstm): LSTM(2048, 256, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=256, out_features=7, bias=True)
# )
# CNN Layers:
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU(inplace=True)
#   (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (5): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (6): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (7): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (8): AdaptiveAvgPool2d(output_size=(1, 1))
# )
#
# LSTM Layers:
# LSTM(2048, 256, num_layers=2, batch_first=True)
#
# Classification Layer:
# Linear(in_features=256, out_features=7, bias=True)

# %%
class FootballDataset(Dataset):
    def __init__(self, data_dir):
        self.data_dir = data_dir
        self.classes = os.listdir(data_dir)
        self.class_to_idx = {c: i for i, c in enumerate(self.classes)}
        self.imgs = self.make_dataset()

    def make_dataset(self):
        images = []
        for cls in self.classes:
            class_dir = os.path.join(self.data_dir, cls)
            if not os.path.isdir(class_dir):
                continue
            for img_name in os.listdir(class_dir):
                img_path = os.path.join(class_dir, img_name)
                item = (img_path, self.class_to_idx[cls])
                images.append(item)
        return images

    def __len__(self):
        return len(self.imgs)

    def __getitem__(self, idx):
        img_path, target = self.imgs[idx]
        img = Image.open(img_path).convert('RGB')
        transform = transforms.Compose([
            transforms.Resize((224, 224)),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        ])
        img = transform(img)
        return img, target

# Set data directories
train_data_dir = 'train'
val_data_dir = 'val'
test_data_dir = 'test'

# Create datasets
train_dataset = FootballDataset(train_data_dir)
val_dataset = FootballDataset(val_data_dir)
test_dataset = FootballDataset(test_data_dir)

# Create dataloaders
batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size)
test_loader = DataLoader(test_dataset, batch_size=batch_size)

# %%
# Define the device (GPU if available, otherwise CPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Initialize the model
model = CNNLSTMModel(num_classes=len(train_dataset.classes)).to(device)

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Training function
def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs=10):
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0
        for i, (inputs, labels) in enumerate(train_loader):
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            running_loss += loss.item()
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()
            
            # Ausgabe der Statistiken nach jedem Batch
            if (i + 1) % 10 == 0:  # Optional: Update alle 10 Batches
                print(f"Epoch {epoch+1}, Batch {i+1}, "
                      f"Batch Loss: {loss.item():.4f}, "
                      f"Batch Acc: {100. * predicted.eq(labels).sum().item() / labels.size(0):.2f}%")

        train_loss = running_loss / len(train_loader)
        train_acc = 100. * correct / total
        
        # Validation am Ende jeder Epoche
        model.eval()
        val_loss = 0.0
        correct = 0
        total = 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                _, predicted = outputs.max(1)
                total += labels.size(0)
                correct += predicted.eq(labels).sum().item()
        
        val_loss = val_loss / len(val_loader)
        val_acc = 100. * correct / total
        
        print(f"End of Epoch {epoch+1}, "
              f"Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}%, "
              f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.2f}%")

# Train the model
train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs=10)
# Out:
# Epoch 1, Batch 10, Batch Loss: 1.6495, Batch Acc: 37.50%
# Epoch 1, Batch 20, Batch Loss: 1.6810, Batch Acc: 31.25%
# Epoch 1, Batch 30, Batch Loss: 1.2487, Batch Acc: 59.38%
# Epoch 1, Batch 40, Batch Loss: 1.1277, Batch Acc: 46.88%
# Epoch 1, Batch 50, Batch Loss: 1.6797, Batch Acc: 40.62%
# Epoch 1, Batch 60, Batch Loss: 1.2407, Batch Acc: 43.75%
# Epoch 1, Batch 70, Batch Loss: 1.4120, Batch Acc: 31.25%
# Epoch 1, Batch 80, Batch Loss: 1.4153, Batch Acc: 43.75%
# Epoch 1, Batch 90, Batch Loss: 1.2746, Batch Acc: 50.00%
# Epoch 1, Batch 100, Batch Loss: 1.0714, Batch Acc: 62.50%
# Epoch 1, Batch 110, Batch Loss: 1.5113, Batch Acc: 43.75%
# Epoch 1, Batch 120, Batch Loss: 1.3716, Batch Acc: 50.00%
# Epoch 1, Batch 130, Batch Loss: 1.0889, Batch Acc: 59.38%
# Epoch 1, Batch 140, Batch Loss: 1.2782, Batch Acc: 53.12%
# Epoch 1, Batch 150, Batch Loss: 1.2749, Batch Acc: 50.00%
# Epoch 1, Batch 160, Batch Loss: 1.2189, Batch Acc: 56.25%
# Epoch 1, Batch 170, Batch Loss: 1.3994, Batch Acc: 43.75%
# Epoch 1, Batch 180, Batch Loss: 1.1422, Batch Acc: 31.25%
# Epoch 1, Batch 190, Batch Loss: 1.1996, Batch Acc: 59.38%
# Epoch 1, Batch 200, Batch Loss: 1.1472, Batch Acc: 43.75%
# Epoch 1, Batch 210, Batch Loss: 1.6372, Batch Acc: 46.88%
# Epoch 1, Batch 220, Batch Loss: 1.3438, Batch Acc: 28.12%
# Epoch 1, Batch 230, Batch Loss: 1.0648, Batch Acc: 59.38%
# Epoch 1, Batch 240, Batch Loss: 1.5537, Batch Acc: 40.62%
# Epoch 1, Batch 250, Batch Loss: 1.1657, Batch Acc: 43.75%
# Epoch 1, Batch 260, Batch Loss: 0.9472, Batch Acc: 68.75%
# Epoch 1, Batch 270, Batch Loss: 1.3845, Batch Acc: 31.25%
# Epoch 1, Batch 280, Batch Loss: 1.2192, Batch Acc: 53.12%
# Epoch 1, Batch 290, Batch Loss: 1.2070, Batch Acc: 53.12%
# Epoch 1, Batch 300, Batch Loss: 1.5113, Batch Acc: 25.00%
# Epoch 1, Batch 310, Batch Loss: 1.3911, Batch Acc: 34.38%
# Epoch 1, Batch 320, Batch Loss: 1.3920, Batch Acc: 53.12%
# Epoch 1, Batch 330, Batch Loss: 1.0717, Batch Acc: 46.88%
# Epoch 1, Batch 340, Batch Loss: 1.2541, Batch Acc: 43.75%
# Epoch 1, Batch 350, Batch Loss: 1.4133, Batch Acc: 56.25%
# Epoch 1, Batch 360, Batch Loss: 1.3912, Batch Acc: 46.88%
# Epoch 1, Batch 370, Batch Loss: 1.3384, Batch Acc: 46.88%
# Epoch 1, Batch 380, Batch Loss: 1.2668, Batch Acc: 40.62%
# Epoch 1, Batch 390, Batch Loss: 0.9963, Batch Acc: 56.25%
# Epoch 1, Batch 400, Batch Loss: 1.1378, Batch Acc: 56.25%
# Epoch 1, Batch 410, Batch Loss: 1.0903, Batch Acc: 50.00%
# Epoch 1, Batch 420, Batch Loss: 1.1843, Batch Acc: 50.00%
# Epoch 1, Batch 430, Batch Loss: 0.9835, Batch Acc: 56.25%
# Epoch 1, Batch 440, Batch Loss: 1.4471, Batch Acc: 43.75%
# Epoch 1, Batch 450, Batch Loss: 1.1280, Batch Acc: 43.75%
# Epoch 1, Batch 460, Batch Loss: 1.3119, Batch Acc: 50.00%
# Epoch 1, Batch 470, Batch Loss: 1.1054, Batch Acc: 62.50%
# Epoch 1, Batch 480, Batch Loss: 1.2163, Batch Acc: 46.88%
# Epoch 1, Batch 490, Batch Loss: 1.2426, Batch Acc: 40.62%
# Epoch 1, Batch 500, Batch Loss: 1.5272, Batch Acc: 34.38%
# Epoch 1, Batch 510, Batch Loss: 1.2624, Batch Acc: 40.62%
# Epoch 1, Batch 520, Batch Loss: 1.3186, Batch Acc: 37.50%
# Epoch 1, Batch 530, Batch Loss: 1.3031, Batch Acc: 50.00%
# Epoch 1, Batch 540, Batch Loss: 1.3840, Batch Acc: 46.88%
# Epoch 1, Batch 550, Batch Loss: 1.1467, Batch Acc: 53.12%
# Epoch 1, Batch 560, Batch Loss: 1.1719, Batch Acc: 53.12%
# Epoch 1, Batch 570, Batch Loss: 1.5187, Batch Acc: 34.38%
# Epoch 1, Batch 580, Batch Loss: 1.4582, Batch Acc: 40.62%
# Epoch 1, Batch 590, Batch Loss: 1.2254, Batch Acc: 40.62%
# Epoch 1, Batch 600, Batch Loss: 1.0859, Batch Acc: 53.12%
# Epoch 1, Batch 610, Batch Loss: 1.1785, Batch Acc: 43.75%
# Epoch 1, Batch 620, Batch Loss: 1.1464, Batch Acc: 34.38%
# Epoch 1, Batch 630, Batch Loss: 1.2250, Batch Acc: 34.38%
# Epoch 1, Batch 640, Batch Loss: 1.3048, Batch Acc: 50.00%
# Epoch 1, Batch 650, Batch Loss: 1.3806, Batch Acc: 40.62%
# Epoch 1, Batch 660, Batch Loss: 1.1308, Batch Acc: 46.88%
# Epoch 1, Batch 670, Batch Loss: 1.2084, Batch Acc: 43.75%
# Epoch 1, Batch 680, Batch Loss: 0.9893, Batch Acc: 56.25%
# Epoch 1, Batch 690, Batch Loss: 1.3571, Batch Acc: 31.25%
# Epoch 1, Batch 700, Batch Loss: 1.1372, Batch Acc: 34.38%
# Epoch 1, Batch 710, Batch Loss: 1.2130, Batch Acc: 50.00%
# Epoch 1, Batch 720, Batch Loss: 1.3047, Batch Acc: 43.75%
# Epoch 1, Batch 730, Batch Loss: 1.1647, Batch Acc: 50.00%
# Epoch 1, Batch 740, Batch Loss: 1.1339, Batch Acc: 43.75%
# Epoch 1, Batch 750, Batch Loss: 1.4846, Batch Acc: 40.62%
# Epoch 1, Batch 760, Batch Loss: 1.1010, Batch Acc: 37.50%
# Epoch 1, Batch 770, Batch Loss: 1.2008, Batch Acc: 50.00%
# Epoch 1, Batch 780, Batch Loss: 1.2269, Batch Acc: 43.75%
# Epoch 1, Batch 790, Batch Loss: 1.3377, Batch Acc: 50.00%
# Epoch 1, Batch 800, Batch Loss: 1.1500, Batch Acc: 46.88%
# Epoch 1, Batch 810, Batch Loss: 1.3569, Batch Acc: 40.62%
# Epoch 1, Batch 820, Batch Loss: 1.0557, Batch Acc: 59.38%
# Epoch 1, Batch 830, Batch Loss: 1.2468, Batch Acc: 59.38%
# Epoch 1, Batch 840, Batch Loss: 1.2770, Batch Acc: 46.88%
# Epoch 1, Batch 850, Batch Loss: 1.0486, Batch Acc: 62.50%
# Epoch 1, Batch 860, Batch Loss: 1.1501, Batch Acc: 37.50%
# Epoch 1, Batch 870, Batch Loss: 1.2340, Batch Acc: 50.00%
# Epoch 1, Batch 880, Batch Loss: 1.1792, Batch Acc: 37.50%
# Epoch 1, Batch 890, Batch Loss: 1.3821, Batch Acc: 37.50%
# Epoch 1, Batch 900, Batch Loss: 1.3989, Batch Acc: 53.12%
# Epoch 1, Batch 910, Batch Loss: 0.9270, Batch Acc: 59.38%
# Epoch 1, Batch 920, Batch Loss: 1.0932, Batch Acc: 56.25%
# Epoch 1, Batch 930, Batch Loss: 1.2110, Batch Acc: 53.12%
# Epoch 1, Batch 940, Batch Loss: 1.4404, Batch Acc: 50.00%
# Epoch 1, Batch 950, Batch Loss: 1.0781, Batch Acc: 59.38%
# Epoch 1, Batch 960, Batch Loss: 0.9034, Batch Acc: 50.00%
# Epoch 1, Batch 970, Batch Loss: 1.2750, Batch Acc: 53.12%
# Epoch 1, Batch 980, Batch Loss: 1.2003, Batch Acc: 37.50%
# Epoch 1, Batch 990, Batch Loss: 1.2070, Batch Acc: 53.12%
# Epoch 1, Batch 1000, Batch Loss: 1.0467, Batch Acc: 59.38%
# Epoch 1, Batch 1010, Batch Loss: 1.3513, Batch Acc: 40.62%
# Epoch 1, Batch 1020, Batch Loss: 1.3224, Batch Acc: 43.75%
# Epoch 1, Batch 1030, Batch Loss: 1.2488, Batch Acc: 50.00%
# Epoch 1, Batch 1040, Batch Loss: 1.3757, Batch Acc: 46.88%
# Epoch 1, Batch 1050, Batch Loss: 1.1307, Batch Acc: 68.75%
# Epoch 1, Batch 1060, Batch Loss: 1.4081, Batch Acc: 40.62%
# Epoch 1, Batch 1070, Batch Loss: 0.9002, Batch Acc: 65.62%
# Epoch 1, Batch 1080, Batch Loss: 1.3533, Batch Acc: 50.00%
# Epoch 1, Batch 1090, Batch Loss: 1.1623, Batch Acc: 40.62%
# Epoch 1, Batch 1100, Batch Loss: 1.2109, Batch Acc: 53.12%
# Epoch 1, Batch 1110, Batch Loss: 1.1491, Batch Acc: 31.25%
# Epoch 1, Batch 1120, Batch Loss: 0.9484, Batch Acc: 62.50%
# Epoch 1, Batch 1130, Batch Loss: 0.9464, Batch Acc: 50.00%
# Epoch 1, Batch 1140, Batch Loss: 0.9225, Batch Acc: 65.62%
# Epoch 1, Batch 1150, Batch Loss: 1.4451, Batch Acc: 34.38%
# Epoch 1, Batch 1160, Batch Loss: 1.0312, Batch Acc: 50.00%
# Epoch 1, Batch 1170, Batch Loss: 1.1326, Batch Acc: 50.00%
# Epoch 1, Batch 1180, Batch Loss: 1.6282, Batch Acc: 37.50%
# Epoch 1, Batch 1190, Batch Loss: 0.9878, Batch Acc: 50.00%
# Epoch 1, Batch 1200, Batch Loss: 1.1953, Batch Acc: 34.38%
# Epoch 1, Batch 1210, Batch Loss: 1.0613, Batch Acc: 59.38%
# Epoch 1, Batch 1220, Batch Loss: 1.0570, Batch Acc: 71.88%
# Epoch 1, Batch 1230, Batch Loss: 1.1706, Batch Acc: 62.50%
# Epoch 1, Batch 1240, Batch Loss: 1.3043, Batch Acc: 43.75%
# Epoch 1, Batch 1250, Batch Loss: 0.9486, Batch Acc: 46.88%
# Epoch 1, Batch 1260, Batch Loss: 1.0964, Batch Acc: 59.38%
# Epoch 1, Batch 1270, Batch Loss: 1.0146, Batch Acc: 56.25%
# Epoch 1, Batch 1280, Batch Loss: 0.9763, Batch Acc: 53.12%
# Epoch 1, Batch 1290, Batch Loss: 1.0075, Batch Acc: 59.38%
# Epoch 1, Batch 1300, Batch Loss: 1.1017, Batch Acc: 37.50%
# Epoch 1, Batch 1310, Batch Loss: 1.0435, Batch Acc: 53.12%
# Epoch 1, Batch 1320, Batch Loss: 1.1538, Batch Acc: 34.38%
# Epoch 1, Batch 1330, Batch Loss: 1.1224, Batch Acc: 46.88%
# Epoch 1, Batch 1340, Batch Loss: 0.9171, Batch Acc: 56.25%
# Epoch 1, Batch 1350, Batch Loss: 1.2910, Batch Acc: 37.50%
# Epoch 1, Batch 1360, Batch Loss: 1.1580, Batch Acc: 53.12%
# Epoch 1, Batch 1370, Batch Loss: 1.1167, Batch Acc: 59.38%
# Epoch 1, Batch 1380, Batch Loss: 1.1414, Batch Acc: 56.25%
# Epoch 1, Batch 1390, Batch Loss: 1.0999, Batch Acc: 53.12%
# Epoch 1, Batch 1400, Batch Loss: 1.4257, Batch Acc: 46.88%
# Epoch 1, Batch 1410, Batch Loss: 1.1804, Batch Acc: 50.00%
# Epoch 1, Batch 1420, Batch Loss: 1.2749, Batch Acc: 46.88%
# Epoch 1, Batch 1430, Batch Loss: 1.1945, Batch Acc: 53.12%
# Epoch 1, Batch 1440, Batch Loss: 1.3125, Batch Acc: 37.50%
# Epoch 1, Batch 1450, Batch Loss: 1.2285, Batch Acc: 46.88%
# Epoch 1, Batch 1460, Batch Loss: 1.3168, Batch Acc: 46.88%
# Epoch 1, Batch 1470, Batch Loss: 0.9955, Batch Acc: 50.00%
# Epoch 1, Batch 1480, Batch Loss: 1.0378, Batch Acc: 59.38%
# Epoch 1, Batch 1490, Batch Loss: 1.1896, Batch Acc: 40.62%
# Epoch 1, Batch 1500, Batch Loss: 1.1752, Batch Acc: 43.75%
# Epoch 1, Batch 1510, Batch Loss: 1.0430, Batch Acc: 50.00%
# Epoch 1, Batch 1520, Batch Loss: 0.9225, Batch Acc: 62.50%
# Epoch 1, Batch 1530, Batch Loss: 1.2376, Batch Acc: 40.62%
# Epoch 1, Batch 1540, Batch Loss: 0.9673, Batch Acc: 53.12%
# Epoch 1, Batch 1550, Batch Loss: 1.3134, Batch Acc: 31.25%
# Epoch 1, Batch 1560, Batch Loss: 1.4564, Batch Acc: 43.75%
# Epoch 1, Batch 1570, Batch Loss: 1.1647, Batch Acc: 56.25%
# Epoch 1, Batch 1580, Batch Loss: 1.0211, Batch Acc: 53.12%
# Epoch 1, Batch 1590, Batch Loss: 1.1900, Batch Acc: 62.50%
# Epoch 1, Batch 1600, Batch Loss: 1.1103, Batch Acc: 43.75%
# Epoch 1, Batch 1610, Batch Loss: 1.1215, Batch Acc: 53.12%
# Epoch 1, Batch 1620, Batch Loss: 1.2740, Batch Acc: 37.50%
# Epoch 1, Batch 1630, Batch Loss: 1.3139, Batch Acc: 46.88%
# Epoch 1, Batch 1640, Batch Loss: 1.2242, Batch Acc: 59.38%
# Epoch 1, Batch 1650, Batch Loss: 1.3234, Batch Acc: 46.88%
# Epoch 1, Batch 1660, Batch Loss: 1.2345, Batch Acc: 53.12%
# Epoch 1, Batch 1670, Batch Loss: 1.1558, Batch Acc: 37.50%
# Epoch 1, Batch 1680, Batch Loss: 1.0670, Batch Acc: 71.88%
# Epoch 1, Batch 1690, Batch Loss: 1.1860, Batch Acc: 59.38%
# Epoch 1, Batch 1700, Batch Loss: 1.2686, Batch Acc: 59.38%
# Epoch 1, Batch 1710, Batch Loss: 1.0910, Batch Acc: 43.75%
# Epoch 1, Batch 1720, Batch Loss: 1.1490, Batch Acc: 46.88%
# Epoch 1, Batch 1730, Batch Loss: 1.1442, Batch Acc: 59.38%
# Epoch 1, Batch 1740, Batch Loss: 1.6384, Batch Acc: 37.50%
# Epoch 1, Batch 1750, Batch Loss: 1.2289, Batch Acc: 53.12%
# Epoch 1, Batch 1760, Batch Loss: 0.9450, Batch Acc: 68.75%
# Epoch 1, Batch 1770, Batch Loss: 1.1805, Batch Acc: 53.12%
# Epoch 1, Batch 1780, Batch Loss: 1.5569, Batch Acc: 40.62%
# Epoch 1, Batch 1790, Batch Loss: 1.1710, Batch Acc: 34.38%
# Epoch 1, Batch 1800, Batch Loss: 1.2264, Batch Acc: 56.25%
# Epoch 1, Batch 1810, Batch Loss: 1.2220, Batch Acc: 40.62%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[49], line 63
#      58         print(f"End of Epoch {epoch+1}, "
#      59               f"Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}%, "
#      60               f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.2f}%")
#      62 # Train the model
# ---> 63 train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs=10)
#
# Cell In[49], line 18, in train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs)
#      16 correct = 0
#      17 total = 0
# ---> 18 for i, (inputs, labels) in enumerate(train_loader):
#      19     inputs, labels = inputs.to(device), labels.to(device)
#      20     optimizer.zero_grad()
#
# File c:\Users\MCI\anaconda3\envs\football_analysis\Lib\site-packages\torch\utils\data\dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#     633 if self._dataset_kind == _DatasetKind.Iterable and \
#     634         self._IterableDataset_len_called is not None and \
#     635         self._num_yielded > self._IterableDataset_len_called:
#
# File c:\Users\MCI\anaconda3\envs\football_analysis\Lib\site-packages\torch\utils\data\dataloader.py:675, in _SingleProcessDataLoaderIter._next_data(self)
#     673 def _next_data(self):
#     674     index = self._next_index()  # may raise StopIteration
# --> 675     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     676     if self._pin_memory:
#     677         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File c:\Users\MCI\anaconda3\envs\football_analysis\Lib\site-packages\torch\utils\data\_utils\fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# Cell In[44], line 25, in FootballDataset.__getitem__(self, idx)
#      23 def __getitem__(self, idx):
#      24     img_path, target = self.imgs[idx]
# ---> 25     img = Image.open(img_path).convert('RGB')
#      26     transform = transforms.Compose([
#      27         transforms.Resize((224, 224)),
#      28         transforms.ToTensor(),
#      29         transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#      30     ])
#      31     img = transform(img)
#
# File c:\Users\MCI\anaconda3\envs\football_analysis\Lib\site-packages\PIL\Image.py:3277, in open(fp, mode, formats)
#    3274     filename = os.path.realpath(os.fspath(fp))
#    3276 if filename:
# -> 3277     fp = builtins.open(filename, "rb")
#    3278     exclusive_fp = True
#    3280 try:
#
# KeyboardInterrupt:
